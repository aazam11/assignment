# %%
#Q1
import scipy.stats as stats

# Sample data
mean = 50
std_dev = 5
sample_size = 100  # Assuming a sample size of 100

# Calculate the standard error
standard_error = std_dev / (sample_size**0.5)

# Calculate the margin of error for a 95% confidence interval
margin_of_error = stats.norm.ppf(0.975) * standard_error

# Calculate the confidence interval
confidence_interval = (mean - margin_of_error, mean + margin_of_error)

print("95% Confidence Interval:", confidence_interval)
# Out:
# 95% Confidence Interval: (49.02001800772997, 50.97998199227003)

# %%
#Q2
import scipy.stats as stats
import numpy as np

# Observed frequencies (actual M&M counts)
observed = np.array([25, 15, 30, 10, 12, 28])  # Replace these values with your actual data

# Expected proportions based on the expected distribution
expected_proportions = np.array([0.20, 0.20, 0.20, 0.10, 0.10, 0.20])  # 20% for each color, adjust as needed

# Calculate the expected frequencies based on expected proportions and the total count
total_count = observed.sum()
expected = expected_proportions * total_count

# Perform the chi-square goodness of fit test
chi_square, p_value = stats.chisquare(f_obs=observed, f_exp=expected)

alpha = 0.05

print("Chi-Square Statistic:", chi_square)
print("p-value:", p_value)

if p_value < alpha:
    print("Reject the null hypothesis: The distribution of M&M colors does not match the expected distribution.")
else:
    print("Fail to reject the null hypothesis: The distribution of M&M colors matches the expected distribution.")
# Out:
# Chi-Square Statistic: 5.916666666666666
# p-value: 0.3144122692086723
# Fail to reject the null hypothesis: The distribution of M&M colors matches the expected distribution.

# %%
#Q3
import scipy.stats as stats

# Create a contingency table
observed_data = [[20, 15], [10, 25], [15, 20]]

# Perform the chi-square test
chi_square, p_value, dof, expected = stats.chi2_contingency(observed_data)

print("Chi-Square Statistic:", chi_square)
print("p-value:", p_value)
# Out:
# Chi-Square Statistic: 5.833333333333334
# p-value: 0.05411376622282158

# %%
#Q4
import scipy.stats as stats

# Sample data
sample_size = 500
smokers = 60

# Calculate the sample proportion
sample_proportion = smokers / sample_size

# Calculate the standard error for proportion
standard_error = ((sample_proportion * (1 - sample_proportion)) / sample_size) ** 0.5

# Calculate the margin of error for a 95% confidence interval
margin_of_error = stats.norm.ppf(0.975) * standard_error

# Calculate the confidence interval
confidence_interval = (sample_proportion - margin_of_error, sample_proportion + margin_of_error)

print("95% Confidence Interval for Smoking Proportion:", confidence_interval)
# Out:
# 95% Confidence Interval for Smoking Proportion: (0.09151638887130707, 0.1484836111286929)

# %%
#Q5
import scipy.stats as stats

# Sample data
mean = 75
std_dev = 12
sample_size = 100

# Calculate the standard error
standard_error = std_dev / (sample_size**0.5)

# Calculate the margin of error for a 90% confidence interval
margin_of_error = stats.norm.ppf(0.95) * standard_error

# Calculate the confidence interval
confidence_interval = (mean - margin_of_error, mean + margin_of_error)

print("90% Confidence Interval:", confidence_interval)
# Out:
# 90% Confidence Interval: (73.02617564765823, 76.97382435234177)

# %%
#Q6
import numpy as np
import matplotlib.pyplot as plt

degrees_of_freedom = 10
x = np.linspace(0, 30, 1000)  # Values for the x-axis
chi_square_distribution = stats.chi2.pdf(x, degrees_of_freedom)

plt.plot(x, chi_square_distribution, label='Chi-Square PDF (df=10)')
plt.fill_between(x, 0, chi_square_distribution, where=(x >= 15), color='gray', alpha=0.5, label='Chi-Square > 15')
plt.xlabel('Chi-Square Statistic')
plt.ylabel('Probability Density')
plt.title('Chi-Square Distribution with df=10')
plt.legend()
plt.show()

# %%
#Q7
import scipy.stats as stats
import numpy as np

# Sample data
sample_size = 1000
coke_preferred = 520

# Calculate the sample proportion
sample_proportion = coke_preferred / sample_size

# Calculate the standard error for proportion
standard_error = np.sqrt((sample_proportion * (1 - sample_proportion)) / sample_size)

# Calculate the margin of error for a 99% confidence interval
margin_of_error = stats.norm.ppf(0.995) * standard_error

# Calculate the confidence interval
confidence_interval = (sample_proportion - margin_of_error, sample_proportion + margin_of_error)

print("99% Confidence Interval for People Preferring Coke:", confidence_interval)
# Out:
# 99% Confidence Interval for People Preferring Coke: (0.4793051576779699, 0.5606948423220302)

# %%
import scipy.stats as stats

# Observed frequencies
observed_tails = 45
observed_heads = 100 - observed_tails  # Total flips minus observed tails

# Expected frequencies for a fair coin
expected_tails = 0.5 * 100  # 50 tails expected for a fair coin flipped 100 times
expected_heads = 100 - expected_tails  # Total flips minus expected tails

# Create observed and expected frequency arrays
observed_frequencies = [observed_heads, observed_tails]
expected_frequencies = [expected_heads, expected_tails]

# Perform the chi-square goodness of fit test
chi_square, p_value = stats.chisquare(f_obs=observed_frequencies, f_exp=expected_frequencies)

alpha = 0.05

print("Chi-Square Statistic:", chi_square)
print("p-value:", p_value)

if p_value < alpha:
    print("Reject the null hypothesis: The coin may be biased towards tails.")
else:
    print("Fail to reject the null hypothesis: There is no significant evidence of bias towards tails.")
# Out:
# Chi-Square Statistic: 1.0
# p-value: 0.31731050786291115
# Fail to reject the null hypothesis: There is no significant evidence of bias towards tails.

# %%
#Q9
import scipy.stats as stats

# Create the contingency table
observed_data = [[60, 140], [30, 170]]

# Perform the chi-square test for independence
chi_square, p_value, dof, expected = stats.chi2_contingency(observed_data)

alpha = 0.05

print("Chi-Square Statistic:", chi_square)
print("p-value:", p_value)

if p_value < alpha:
    print("Reject the null hypothesis: There is a significant association between smoking status and lung cancer diagnosis.")
else:
    print("Fail to reject the null hypothesis: There is no significant association between smoking status and lung cancer diagnosis.")
# Out:
# Chi-Square Statistic: 12.057347670250895
# p-value: 0.0005158863863703744
# Reject the null hypothesis: There is a significant association between smoking status and lung cancer diagnosis.

# %%
#Q10
import scipy.stats as stats

# Create the contingency table
observed_data = [[200, 150, 150], [225, 175, 100]]

# Perform the chi-square test for independence
chi_square, p_value, dof, expected = stats.chi2_contingency(observed_data)

alpha = 0.01

print("Chi-Square Statistic:", chi_square)
print("p-value:", p_value)

if p_value < alpha:
    print("Reject the null hypothesis: There is a significant association between chocolate preference and country of origin.")
else:
    print("Fail to reject the null hypothesis: There is no significant association between chocolate preference and country of origin.")
# Out:
# Chi-Square Statistic: 13.393665158371041
# p-value: 0.0012348168997745918
# Reject the null hypothesis: There is a significant association between chocolate preference and country of origin.

# %%
#Q11
import scipy.stats as stats

# Sample data
sample_mean = 72
sample_std_dev = 10
sample_size = 30
population_mean = 70  # The hypothesized population mean

# Calculate the t-statistic
t_statistic = (sample_mean - population_mean) / (sample_std_dev / (sample_size**0.5))

alpha = 0.05

# Calculate the degrees of freedom
degrees_of_freedom = sample_size - 1

# Calculate the critical t-value for a two-tailed test
critical_t_value = stats.t.ppf(1 - alpha / 2, degrees_of_freedom)

print("t-Statistic:", t_statistic)
print("Critical t-Value:", critical_t_value)

if abs(t_statistic) > critical_t_value:
    print("Reject the null hypothesis: The population mean is significantly different from 70.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference in the population mean and 70.")
# Out:
# t-Statistic: 1.0954451150103321
# Critical t-Value: 2.045229642132703
# Fail to reject the null hypothesis: There is no significant difference in the population mean and 70.
