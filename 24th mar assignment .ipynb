# %% [markdown]
# #Q1
# #The key features of the wine quality dataset typically include various chemical properties of wines. Common features include:
#
# Fixed Acidity: Acidity is a crucial factor influencing the taste of wine.
# Volatile Acidity: Higher levels of volatile acidity can lead to unpleasant vinegar-like flavors.
# Citric Acid: Adds freshness and flavor to wines.
# Residual Sugar: The amount of sugar left after fermentation.
# Chlorides: Excessive chloride levels can result in a salty taste.
# Free Sulfur Dioxide: Sulfur dioxide is used as a preservative in winemaking.
# Total Sulfur Dioxide: Affects the wine's stability and aging.
# Density: Influences the mouthfeel of wine.
# pH: Indicates the acidity or basicity of the wine.
# Sulphates: Contribute to the wine's taste and smell.
# Alcohol: The alcohol content of the wine.
# The importance of each feature in predicting wine quality depends on the context of the dataset and the specific model being used. Different models may give varying degrees of importance to these features.

# %% [markdown]
# #Q2
# Handling missing data is crucial for accurate modeling. Common techniques include:
#
# Imputation: Replace missing values with estimated values. Techniques include mean imputation, median imputation, and regression imputation.
# Deletion: Remove rows or columns with missing data.
# Prediction Models: Use other variables to predict missing values.
# Advantages and disadvantages:
#
# Mean/Median Imputation: Simple, but it ignores relationships between variables.
# Regression Imputation: Considers relationships but assumes a linear relationship.
# Deletion: Preserves data integrity but may lead to information loss.

# %% [markdown]
# #Q3
# Factors influencing student performance can include:
#
# Study Habits
# Attendance
# Parental Involvement
# Motivation
# Teacher Quality
# Health and Well-being
# Analyzing these factors involves statistical techniques such as regression analysis, correlation, and hypothesis testing to identify significant variables.

# %% [markdown]
# #Q4
# Feature engineering involves creating new variables or transforming existing ones to improve model performance. For student performance, you might create features like:
#
# Study Time
# Attendance Percentage
# Parental Involvement Index

# %%
#Q5

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# Load the wine quality dataset
wine_data = pd.read_csv('wine quality.csv')  # Replace 'wine_quality.csv' with the actual file name

# Plot the distribution of each feature
plt.figure(figsize=(15, 10))
for i, feature in enumerate(wine_data.columns):
    plt.subplot(3, 4, i + 1)
    sns.histplot(wine_data[feature], kde=True)
    plt.title(f'Distribution of {feature}')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 16
#      14 plt.figure(figsize=(15, 10))
#      15 for i, feature in enumerate(wine_data.columns):
# ---> 16     plt.subplot(3, 4, i + 1)
#      17     sns.histplot(wine_data[feature], kde=True)
#      18     plt.title(f'Distribution of {feature}')
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/pyplot.py:1264, in subplot(*args, **kwargs)
#    1261 fig = gcf()
#    1263 # First, search for an existing subplot with a matching spec.
# -> 1264 key = SubplotSpec._from_subplot_args(fig, args)
#    1266 for ax in fig.axes:
#    1267     # if we found an Axes at the position sort out if we can re-use it
#    1268     if hasattr(ax, 'get_subplotspec') and ax.get_subplotspec() == key:
#    1269         # if the user passed no kwargs, re-use
#
# ...

# %%
#Q6

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Load the wine quality dataset
wine_data = pd.read_csv('wine quality.csv') 

# Separate features and target variable
X = wine_data.drop('total sulfur dioxide', axis=1)
y = wine_data['total sulfur dioxide']

# Standardize the features
X_standardized = StandardScaler().fit_transform(X)

# Perform PCA
pca = PCA()
X_pca = pca.fit_transform(X_standardized)

# Plot the explained variance ratio
plt.plot(range(1, len(pca.explained_variance_ratio_) + 1), 
         np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance by Principal Components')
plt.show()

# Determine the minimum number of components to explain 90% of the variance
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)
min_components = np.argmax(cumulative_variance >= 0.9) + 1
print(f'Minimum number of components to explain 90% of variance: {min_components}')
# Out:
# Minimum number of components to explain 90% of variance: 8
